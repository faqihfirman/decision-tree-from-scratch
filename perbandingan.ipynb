# %%
# Import DecisionTreeClassifier dari sklearn
from sklearn.tree import DecisionTreeClassifier as SklearnDT

# Training model sklearn
model_sklearn = SklearnDT(
    criterion='entropy',
    max_depth=10,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42
)
model_sklearn.fit(X_latih, y_latih)

# Prediksi
y_pred_sklearn = model_sklearn.predict(X_uji)
akurasi_sklearn = accuracy_score(y_uji, y_pred_sklearn)

# Perbandingan
print("=" * 70)
print("PERBANDINGAN MODEL")
print("=" * 70)
print(f"Akurasi Model Manual:  {akurasi_uji * 100:.2f}%")
print(f"Akurasi Model Sklearn: {akurasi_sklearn * 100:.2f}%")
print(f"Selisih:               {abs(akurasi_uji - akurasi_sklearn) * 100:.2f}%")
print("=" * 70)

# Visualisasi perbandingan
fig, ax = plt.subplots(figsize=(8, 6))
models = ['Manual\nImplementation', 'Sklearn\nImplementation']
accuracies = [akurasi_uji * 100, akurasi_sklearn * 100]
colors = ['steelblue', 'coral']

bars = ax.bar(models, accuracies, color=colors, edgecolor='black', alpha=0.8)
ax.set_ylabel('Akurasi (%)', fontsize=12)
ax.set_title('Perbandingan Akurasi Model', fontsize=14, fontweight='bold')
ax.set_ylim([0, 105])
ax.grid(axis='y', alpha=0.3)

# Tambahkan nilai di atas bar
for bar, acc in zip(bars, accuracies):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height + 1,
            f'{acc:.2f}%', ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()
